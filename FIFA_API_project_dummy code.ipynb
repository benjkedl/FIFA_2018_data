# %%
import requests
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

fifa_url = 'https://worldcup.sfg.io/teams/results'
#pop_url = 'http://api.population.io/static/docs/api-docs/countries'

# %%
#request data on all the teams in the 2018 World cup
response = requests.get(fifa_url).json()
teams_df = pd.DataFrame(response)
teams_df.index = teams_df['country']
del teams_df['country']
del teams_df['alternate_name']
teams_df
# Out:
#                 draws fifa_code  games_played  goal_differential  \
# country
# Korea Republic      0       KOR             3                  0
# Germany             0       GER             3                 -2
# Serbia              0       SRB             3                 -2
# Costa Rica          1       CRC             3                 -3
# Belgium             0       BEL             7                 10
# Poland              0       POL             3                 -3
# Senegal             1       SEN             3                  0
# England             1       ENG             7                  4
# France              1       FRA             7                  8
# Croatia             2       CRO             7                  5
# Panama              0       PAN             3                 -9
# Tunisia             0       TUN             3                 -3
# Argentina           1       ARG             4                 -3
# Portugal            2       POR             4                  0
# Mexico              0       MEX             4                 -3
# Japan               1       JPN             4                 -1
# Colombia            1       COL             4                  3
# Switzerland         2       SUI             4                  0
# Uruguay             0       URU             5                  4
# Brazil              1       BRA             5                  5
# Spain               3       ESP             4                  1
# Saudi Arabia        0       KSA             3                 -5
# Egypt               0       EGY             3                 -4
# Morocco             1       MAR             3                 -2
# Iran                1       IRN             3                  0
# Sweden              0       SWE             5                  2
# Australia           1       AUS             3                 -3
# Peru                0       PER             3                  0
# Iceland             1       ISL             3                 -3
# Nigeria             0       NGA             3                 -1
# Russia              2       RUS             5                  4
# Denmark             3       DEN             4                  1
#
#                 goals_against  goals_for  group_id group_letter  id  losses  \
# country
# Korea Republic              3          3         6            F  24       2
# Germany                     4          2         6            F  21       2
# Serbia                      4          2         5            E  20       2
# Costa Rica                  5          2         5            E  19       2
# Belgium                     6         16         7            G  25       1
# Poland                      5          2         8            H  29       2
# Senegal                     4          4         8            H  30       1
# England                     8         12         7            G  28       3
# France                      6         14         3            C   9       0
# Croatia                     9         14         4            D  15       1
# Panama                     11          2         7            G  26       3
# Tunisia                     8          5         7            G  27       2
# Argentina                   9          6         4            D  13       2
# Portugal                    6          6         2            B   5       1
# Mexico                      6          3         6            F  22       2
# Japan                       7          6         8            H  32       2
# Colombia                    3          6         8            H  31       1
# Switzerland                 5          5         5            E  18       1
# Uruguay                     3          7         1            A   4       1
# Brazil                      3          8         5            E  17       1
# Spain                       6          7         2            B   6       0
# Saudi Arabia                7          2         1            A   2       2
# Egypt                       6          2         1            A   3       3
# Morocco                     4          2         2            B   7       2
# Iran                        2          2         2            B   8       1
# Sweden                      4          6         6            F  23       2
# Australia                   5          2         3            C  10       2
# Peru                        2          2         3            C  11       2
# Iceland                     5          2         4            D  14       2
# Nigeria                     4          3         4            D  16       2
# Russia                      7         11         1            A   1       1
# Denmark                     2          3         3            C  12       0
#
#                 points  wins
# country
# Korea Republic       3     1
# Germany              3     1
# Serbia               3     1
# Costa Rica           1     0
# Belgium             18     6
# Poland               3     1
# Senegal              4     1
# England             10     3
# France              19     6
# Croatia             14     4
# Panama               0     0
# Tunisia              3     1
# Argentina            4     1
# Portugal             5     1
# Mexico               6     2
# Japan                4     1
# Colombia             7     2
# Switzerland          5     1
# Uruguay             12     4
# Brazil              10     3
# Spain                6     1
# Saudi Arabia         3     1
# Egypt                0     0
# Morocco              1     0
# Iran                 4     1
# Sweden               9     3
# Australia            1     0
# Peru                 3     1
# Iceland              1     0
# Nigeria              3     1
# Russia               8     2
# Denmark              6     1

# %%
teams_df = pd.DataFrame(response)
teams_df.index = teams_df['country']
del teams_df['alternate_name']
teams_df.head()
# Out:
#                        country  draws fifa_code  games_played  \
# country
# Korea Republic  Korea Republic      0       KOR             3
# Germany                Germany      0       GER             3
# Serbia                  Serbia      0       SRB             3
# Costa Rica          Costa Rica      1       CRC             3
# Belgium                Belgium      0       BEL             7
#
#                 goal_differential  goals_against  goals_for  group_id  \
# country
# Korea Republic                  0              3          3         6
# Germany                        -2              4          2         6
# Serbia                         -2              4          2         5
# Costa Rica                     -3              5          2         5
# Belgium                        10              6         16         7
#
#                group_letter  id  losses  points  wins
# country
# Korea Republic            F  24       2       3     1
# Germany                   F  21       2       3     1
# Serbia                    E  20       2       3     1
# Costa Rica                E  19       2       1     0
# Belgium                   G  25       1      18     6

# %%
matches_url = 'https://worldcup.sfg.io/matches'
match_df = pd.DataFrame(requests.get(matches_url).json())

first_stage = match_df[match_df['stage_name']=='First stage']
round_sixteen = match_df[match_df['stage_name']=='Round of 16']
quartfinals = match_df[match_df['stage_name']=='Quarter-finals']
semifinals = match_df[match_df['stage_name']=='Semi-finals']
final = match_df[match_df['stage_name']=='Final']

match_df
# Out:
#    attendance                                          away_team  \
# 0       78011  {'country': 'Saudi Arabia', 'code': 'KSA', 'go...
# 1       27015  {'country': 'Uruguay', 'code': 'URU', 'goals':...
# 2       62548  {'country': 'Iran', 'code': 'IRN', 'goals': 1,...
# 3       43866  {'country': 'Spain', 'code': 'ESP', 'goals': 3...
# 4       41279  {'country': 'Australia', 'code': 'AUS', 'goals...
# 5       44190  {'country': 'Iceland', 'code': 'ISL', 'goals':...
# 6       40502  {'country': 'Denmark', 'code': 'DEN', 'goals':...
# 7       31136  {'country': 'Nigeria', 'code': 'NGA', 'goals':...
# 8       41432  {'country': 'Serbia', 'code': 'SRB', 'goals': ...
# 9       78011  {'country': 'Mexico', 'code': 'MEX', 'goals': ...
# 10      43109  {'country': 'Switzerland', 'code': 'SUI', 'goa...
# 11      42300  {'country': 'Korea Republic', 'code': 'KOR', '...
# 12      43257  {'country': 'Panama', 'code': 'PAN', 'goals': ...
# 13      41064  {'country': 'England', 'code': 'ENG', 'goals':...
# 14      40842  {'country': 'Japan', 'code': 'JPN', 'goals': 2...
# 15      44190  {'country': 'Senegal', 'code': 'SEN', 'goals':...
# 16      64468  {'country': 'Egypt', 'code': 'EGY', 'goals': 1...
# 17      78011  {'country': 'Morocco', 'code': 'MAR', 'goals':...
# 18      42678  {'country': 'Saudi Arabia', 'code': 'KSA', 'go...
# 19      42718  {'country': 'Spain', 'code': 'ESP', 'goals': 1...
# 20      40727  {'country': 'Australia', 'code': 'AUS', 'goals...
# 21      32789  {'country': 'Peru', 'code': 'PER', 'goals': 0,...
# 22      43319  {'country': 'Croatia', 'code': 'CRO', 'goals':...
# 23      64468  {'country': 'Costa Rica', 'code': 'CRC', 'goal...
# 24      40904  {'country': 'Iceland', 'code': 'ISL', 'goals':...
# 25      33167  {'country': 'Switzerland', 'code': 'SUI', 'goa...
# 26      44190  {'country': 'Tunisia', 'code': 'TUN', 'goals':...
# 27      43472  {'country': 'Mexico', 'code': 'MEX', 'goals': ...
# 28      44287  {'country': 'Sweden', 'code': 'SWE', 'goals': ...
# 29      43319  {'country': 'Panama', 'code': 'PAN', 'goals': ...
# ..        ...                                                ...
# 34      33973  {'country': 'Morocco', 'code': 'MAR', 'goals':...
# 35      41685  {'country': 'Portugal', 'code': 'POR', 'goals'...
# 36      78011  {'country': 'France', 'code': 'FRA', 'goals': ...
# 37      44073  {'country': 'Peru', 'code': 'PER', 'goals': 2,...
# 38      43472  {'country': 'Croatia', 'code': 'CRO', 'goals':...
# 39      64468  {'country': 'Argentina', 'code': 'ARG', 'goals...
# 40      41835  {'country': 'Germany', 'code': 'GER', 'goals':...
# 41      33061  {'country': 'Sweden', 'code': 'SWE', 'goals': ...
# 42      43319  {'country': 'Costa Rica', 'code': 'CRC', 'goal...
# 43      44190  {'country': 'Brazil', 'code': 'BRA', 'goals': ...
# 44      42189  {'country': 'Poland', 'code': 'POL', 'goals': ...
# 45      41970  {'country': 'Colombia', 'code': 'COL', 'goals'...
# 46      33973  {'country': 'Belgium', 'code': 'BEL', 'goals':...
# 47      37168  {'country': 'Tunisia', 'code': 'TUN', 'goals':...
# 48      42873  {'country': 'Argentina', 'code': 'ARG', 'goals...
# 49      44287  {'country': 'Portugal', 'code': 'POR', 'goals'...
# 50      78011  {'country': 'Russia', 'code': 'RUS', 'goals': ...
# 51      40851  {'country': 'Denmark', 'code': 'DEN', 'goals':...
# 52      41970  {'country': 'Mexico', 'code': 'MEX', 'goals': ...
# 53      41466  {'country': 'Japan', 'code': 'JPN', 'goals': 2...
# 54      64042  {'country': 'Switzerland', 'code': 'SUI', 'goa...
# 55      44190  {'country': 'England', 'code': 'ENG', 'goals':...
# 56      43319  {'country': 'France', 'code': 'FRA', 'goals': ...
# 57      42873  {'country': 'Belgium', 'code': 'BEL', 'goals':...
# 58      39991  {'country': 'England', 'code': 'ENG', 'goals':...
# 59      44287  {'country': 'Croatia', 'code': 'CRO', 'goals':...
# 60      64286  {'country': 'Belgium', 'code': 'BEL', 'goals':...
# 61      78011  {'country': 'England', 'code': 'ENG', 'goals':...
# 62      64406  {'country': 'England', 'code': 'ENG', 'goals':...
# 63      78011  {'country': 'Croatia', 'code': 'CRO', 'goals':...
#
#    away_team_country                                   away_team_events  \
# 0       Saudi Arabia  [{'id': 12, 'type_of_event': 'substitution-in'...
# 1            Uruguay  [{'id': 15, 'type_of_event': 'substitution-in'...
# 2               Iran  [{'id': 22, 'type_of_event': 'yellow-card', 'p...
# 3              Spain  [{'id': 37, 'type_of_event': 'yellow-card', 'p...
# 4          Australia  [{'id': 50, 'type_of_event': 'yellow-card', 'p...
# 5            Iceland  [{'id': 63, 'type_of_event': 'goal', 'player':...
# 6            Denmark  [{'id': 70, 'type_of_event': 'substitution-in'...
# 7            Nigeria  [{'id': 81, 'type_of_event': 'goal-own', 'play...
# 8             Serbia  [{'id': 101, 'type_of_event': 'goal', 'player'...
# 9             Mexico  [{'id': 115, 'type_of_event': 'goal', 'player'...
# 10       Switzerland  [{'id': 133, 'type_of_event': 'yellow-card', '...
# 11    Korea Republic  [{'id': 150, 'type_of_event': 'yellow-card', '...
# 12            Panama  [{'id': 167, 'type_of_event': 'yellow-card', '...
# 13           England  [{'id': 189, 'type_of_event': 'goal', 'player'...
# 14             Japan  [{'id': 204, 'type_of_event': 'goal-penalty', ...
# 15           Senegal  [{'id': 227, 'type_of_event': 'yellow-card', '...
# 16             Egypt  [{'id': 241, 'type_of_event': 'goal-own', 'pla...
# 17           Morocco  [{'id': 260, 'type_of_event': 'yellow-card', '...
# 18      Saudi Arabia  [{'id': 277, 'type_of_event': 'substitution-ou...
# 19             Spain  [{'id': 289, 'type_of_event': 'goal', 'player'...
# 20         Australia  [{'id': 357, 'type_of_event': 'goal-penalty', ...
# 21              Peru  [{'id': 370, 'type_of_event': 'yellow-card', '...
# 22           Croatia  [{'id': 387, 'type_of_event': 'yellow-card', '...
# 23        Costa Rica  [{'id': 413, 'type_of_event': 'substitution-ou...
# 24           Iceland  [{'id': 432, 'type_of_event': 'substitution-ou...
# 25       Switzerland  [{'id': 447, 'type_of_event': 'substitution-ou...
# 26           Tunisia  [{'id': 462, 'type_of_event': 'yellow-card', '...
# 27            Mexico  [{'id': 482, 'type_of_event': 'goal-penalty', ...
# 28            Sweden  [{'id': 503, 'type_of_event': 'goal', 'player'...
# 29            Panama  [{'id': 521, 'type_of_event': 'yellow-card', '...
# ..               ...                                                ...
# 34           Morocco  [{'id': 617, 'type_of_event': 'goal', 'player'...
# 35          Portugal  [{'id': 624, 'type_of_event': 'yellow-card', '...
# 36            France  [{'id': 667, 'type_of_event': 'substitution-ou...
# 37              Peru  [{'id': 662, 'type_of_event': 'goal', 'player'...
# 38           Croatia  [{'id': 694, 'type_of_event': 'yellow-card', '...
# 39         Argentina  [{'id': 695, 'type_of_event': 'goal', 'player'...
# 40           Germany  [{'id': 748, 'type_of_event': 'substitution-ou...
# 41            Sweden  [{'id': 741, 'type_of_event': 'yellow-card', '...
# 42        Costa Rica  [{'id': 778, 'type_of_event': 'yellow-card', '...
# 43            Brazil  [{'id': 776, 'type_of_event': 'substitution-ou...
# 44            Poland  [{'id': 822, 'type_of_event': 'goal', 'player'...
# 45          Colombia  [{'id': 816, 'type_of_event': 'substitution-ou...
# 46           Belgium  [{'id': 843, 'type_of_event': 'yellow-card', '...
# 47           Tunisia  [{'id': 846, 'type_of_event': 'goal-own', 'pla...
# 48         Argentina  [{'id': 876, 'type_of_event': 'yellow-card', '...
# 49          Portugal  [{'id': 904, 'type_of_event': 'goal', 'player'...
# 50            Russia  [{'id': 919, 'type_of_event': 'goal-own', 'pla...
# 51           Denmark  [{'id': 942, 'type_of_event': 'goal', 'player'...
# 52            Mexico  [{'id': 963, 'type_of_event': 'yellow-card', '...
# 53             Japan  [{'id': 983, 'type_of_event': 'yellow-card', '...
# 54       Switzerland  [{'id': 998, 'type_of_event': 'yellow-card', '...
# 55           England  [{'id': 1015, 'type_of_event': 'yellow-card', ...
# 56            France  [{'id': 1039, 'type_of_event': 'yellow-card', ...
# 57           Belgium  [{'id': 1059, 'type_of_event': 'goal', 'player...
# 58           England  [{'id': 1076, 'type_of_event': 'goal', 'player...
# 59           Croatia  [{'id': 1095, 'type_of_event': 'yellow-card', ...
# 60           Belgium  [{'id': 1122, 'type_of_event': 'substitution-o...
# 61           England  [{'id': 1137, 'type_of_event': 'goal', 'player...
# 62           England  [{'id': 1163, 'type_of_event': 'substitution-o...
# 63           Croatia  [{'id': 1178, 'type_of_event': 'goal-own', 'pl...
#
#                                  away_team_statistics              datetime  \
# 0   {'country': 'Saudi Arabia', 'attempts_on_goal'...  2018-06-14T15:00:00Z
# 1   {'country': 'Uruguay', 'attempts_on_goal': 14,...  2018-06-15T12:00:00Z
# 2   {'country': 'Iran', 'attempts_on_goal': 8, 'on...  2018-06-15T15:00:00Z
# 3   {'country': 'Spain', 'attempts_on_goal': 12, '...  2018-06-15T18:00:00Z
# 4   {'country': 'Australia', 'attempts_on_goal': 4...  2018-06-16T10:00:00Z
# 5   {'country': 'Iceland', 'attempts_on_goal': 9, ...  2018-06-16T13:00:00Z
# 6   {'country': 'Denmark', 'attempts_on_goal': 10,...  2018-06-16T16:00:00Z
# 7   {'country': 'Nigeria', 'attempts_on_goal': 14,...  2018-06-16T19:00:00Z
# 8   {'country': 'Serbia', 'attempts_on_goal': 10, ...  2018-06-17T12:00:00Z
# 9   {'country': 'Mexico', 'attempts_on_goal': 12, ...  2018-06-17T15:00:00Z
# 10  {'country': 'Switzerland', 'attempts_on_goal':...  2018-06-17T18:00:00Z
# 11  {'country': 'Korea Republic', 'attempts_on_goa...  2018-06-18T12:00:00Z
# 12  {'country': 'Panama', 'attempts_on_goal': 6, '...  2018-06-18T15:00:00Z
# 13  {'country': 'England', 'attempts_on_goal': 17,...  2018-06-18T18:00:00Z
# 14  {'country': 'Japan', 'attempts_on_goal': 14, '...  2018-06-19T12:00:00Z
# 15  {'country': 'Senegal', 'attempts_on_goal': 8, ...  2018-06-19T15:00:00Z
# 16  {'country': 'Egypt', 'attempts_on_goal': 13, '...  2018-06-19T18:00:00Z
# 17  {'country': 'Morocco', 'attempts_on_goal': 16,...  2018-06-20T12:00:00Z
# 18  {'country': 'Saudi Arabia', 'attempts_on_goal'...  2018-06-20T15:00:00Z
# 19  {'country': 'Spain', 'attempts_on_goal': 17, '...  2018-06-20T18:00:00Z
# 20  {'country': 'Australia', 'attempts_on_goal': 1...  2018-06-21T12:00:00Z
# 21  {'country': 'Peru', 'attempts_on_goal': 10, 'o...  2018-06-21T15:00:00Z
# 22  {'country': 'Croatia', 'attempts_on_goal': 15,...  2018-06-21T18:00:00Z
# 23  {'country': 'Costa Rica', 'attempts_on_goal': ...  2018-06-22T12:00:00Z
# 24  {'country': 'Iceland', 'attempts_on_goal': 10,...  2018-06-22T15:00:00Z
# 25  {'country': 'Switzerland', 'attempts_on_goal':...  2018-06-22T18:00:00Z
# 26  {'country': 'Tunisia', 'attempts_on_goal': 15,...  2018-06-23T12:00:00Z
# 27  {'country': 'Mexico', 'attempts_on_goal': 13, ...  2018-06-23T15:00:00Z
# 28  {'country': 'Sweden', 'attempts_on_goal': 8, '...  2018-06-23T18:00:00Z
# 29  {'country': 'Panama', 'attempts_on_goal': 6, '...  2018-06-24T12:00:00Z
# ..                                                ...                   ...
# 34  {'country': 'Morocco', 'attempts_on_goal': 6, ...  2018-06-25T18:00:00Z
# 35  {'country': 'Portugal', 'attempts_on_goal': 14...  2018-06-25T18:00:00Z
# 36  {'country': 'France', 'attempts_on_goal': 11, ...  2018-06-26T14:00:00Z
# 37  {'country': 'Peru', 'attempts_on_goal': 4, 'on...  2018-06-26T14:00:00Z
# 38  {'country': 'Croatia', 'attempts_on_goal': 13,...  2018-06-26T18:00:00Z
# 39  {'country': 'Argentina', 'attempts_on_goal': 8...  2018-06-26T18:00:00Z
# 40  {'country': 'Germany', 'attempts_on_goal': 26,...  2018-06-27T14:00:00Z
# 41  {'country': 'Sweden', 'attempts_on_goal': 13, ...  2018-06-27T14:00:00Z
# 42  {'country': 'Costa Rica', 'attempts_on_goal': ...  2018-06-27T18:00:00Z
# 43  {'country': 'Brazil', 'attempts_on_goal': 13, ...  2018-06-27T18:00:00Z
# 44  {'country': 'Poland', 'attempts_on_goal': 11, ...  2018-06-28T14:00:00Z
# 45  {'country': 'Colombia', 'attempts_on_goal': 4,...  2018-06-28T14:00:00Z
# 46  {'country': 'Belgium', 'attempts_on_goal': 15,...  2018-06-28T18:00:00Z
# 47  {'country': 'Tunisia', 'attempts_on_goal': 15,...  2018-06-28T18:00:00Z
# 48  {'country': 'Argentina', 'attempts_on_goal': 9...  2018-06-30T14:00:00Z
# 49  {'country': 'Portugal', 'attempts_on_goal': 19...  2018-06-30T18:00:00Z
# 50  {'country': 'Russia', 'attempts_on_goal': 6, '...  2018-07-01T14:00:00Z
# 51  {'country': 'Denmark', 'attempts_on_goal': 15,...  2018-07-01T18:00:00Z
# 52  {'country': 'Mexico', 'attempts_on_goal': 13, ...  2018-07-02T14:00:00Z
# 53  {'country': 'Japan', 'attempts_on_goal': 11, '...  2018-07-02T18:00:00Z
# 54  {'country': 'Switzerland', 'attempts_on_goal':...  2018-07-03T14:00:00Z
# 55  {'country': 'England', 'attempts_on_goal': 16,...  2018-07-03T18:00:00Z
# 56  {'country': 'France', 'attempts_on_goal': 11, ...  2018-07-06T14:00:00Z
# 57  {'country': 'Belgium', 'attempts_on_goal': 8, ...  2018-07-06T18:00:00Z
# 58  {'country': 'England', 'attempts_on_goal': 12,...  2018-07-07T14:00:00Z
# 59  {'country': 'Croatia', 'attempts_on_goal': 17,...  2018-07-07T18:00:00Z
# 60  {'country': 'Belgium', 'attempts_on_goal': 9, ...  2018-07-10T18:00:00Z
# 61  {'country': 'England', 'attempts_on_goal': 11,...  2018-07-11T18:00:00Z
# 62  {'country': 'England', 'attempts_on_goal': 15,...  2018-07-14T14:00:00Z
# 63  {'country': 'Croatia', 'attempts_on_goal': 15,...  2018-07-15T15:00:00Z
#
#       fifa_id                                          home_team  \
# 0   300331503  {'country': 'Russia', 'code': 'RUS', 'goals': ...
# 1   300353632  {'country': 'Egypt', 'code': 'EGY', 'goals': 0...
# 2   300331526  {'country': 'Morocco', 'code': 'MAR', 'goals':...
# 3   300331524  {'country': 'Portugal', 'code': 'POR', 'goals'...
# 4   300331533  {'country': 'France', 'code': 'FRA', 'goals': ...
# 5   300331515  {'country': 'Argentina', 'code': 'ARG', 'goals...
# 6   300331528  {'country': 'Peru', 'code': 'PER', 'goals': 0,...
# 7   300331523  {'country': 'Croatia', 'code': 'CRO', 'goals':...
# 8   300331529  {'country': 'Costa Rica', 'code': 'CRC', 'goal...
# 9   300331502  {'country': 'Germany', 'code': 'GER', 'goals':...
# 10  300331525  {'country': 'Brazil', 'code': 'BRA', 'goals': ...
# 11  300331499  {'country': 'Sweden', 'code': 'SWE', 'goals': ...
# 12  300331539  {'country': 'Belgium', 'code': 'BEL', 'goals':...
# 13  300331554  {'country': 'Tunisia', 'code': 'TUN', 'goals':...
# 14  300331550  {'country': 'Colombia', 'code': 'COL', 'goals'...
# 15  300331545  {'country': 'Poland', 'code': 'POL', 'goals': ...
# 16  300331495  {'country': 'Russia', 'code': 'RUS', 'goals': ...
# 17  300331511  {'country': 'Portugal', 'code': 'POR', 'goals'...
# 18  300331530  {'country': 'Uruguay', 'code': 'URU', 'goals':...
# 19  300331496  {'country': 'Iran', 'code': 'IRN', 'goals': 0,...
# 20  300331518  {'country': 'Denmark', 'code': 'DEN', 'goals':...
# 21  300331527  {'country': 'France', 'code': 'FRA', 'goals': ...
# 22  300331513  {'country': 'Argentina', 'code': 'ARG', 'goals...
# 23  300331540  {'country': 'Brazil', 'code': 'BRA', 'goals': ...
# 24  300331497  {'country': 'Nigeria', 'code': 'NGA', 'goals':...
# 25  300340183  {'country': 'Serbia', 'code': 'SRB', 'goals': ...
# 26  300331547  {'country': 'Belgium', 'code': 'BEL', 'goals':...
# 27  300331549  {'country': 'Korea Republic', 'code': 'KOR', '...
# 28  300331501  {'country': 'Germany', 'code': 'GER', 'goals':...
# 29  300331546  {'country': 'England', 'code': 'ENG', 'goals':...
# ..        ...                                                ...
# 34  300340184  {'country': 'Spain', 'code': 'ESP', 'goals': 2...
# 35  300331500  {'country': 'Iran', 'code': 'IRN', 'goals': 1,...
# 36  300331512  {'country': 'Denmark', 'code': 'DEN', 'goals':...
# 37  300331506  {'country': 'Australia', 'code': 'AUS', 'goals...
# 38  300331510  {'country': 'Iceland', 'code': 'ISL', 'goals':...
# 39  300331519  {'country': 'Nigeria', 'code': 'NGA', 'goals':...
# 40  300331532  {'country': 'Korea Republic', 'code': 'KOR', '...
# 41  300331548  {'country': 'Mexico', 'code': 'MEX', 'goals': ...
# 42  300331534  {'country': 'Switzerland', 'code': 'SUI', 'goa...
# 43  300331521  {'country': 'Serbia', 'code': 'SRB', 'goals': ...
# 44  300331507  {'country': 'Japan', 'code': 'JPN', 'goals': 0...
# 45  300331553  {'country': 'Senegal', 'code': 'SEN', 'goals':...
# 46  300340182  {'country': 'England', 'code': 'ENG', 'goals':...
# 47  300331520  {'country': 'Panama', 'code': 'PAN', 'goals': ...
# 48  300331537  {'country': 'France', 'code': 'FRA', 'goals': ...
# 49  300331544  {'country': 'Uruguay', 'code': 'URU', 'goals':...
# 50  300331517  {'country': 'Spain', 'code': 'ESP', 'goals': 1...
# 51  300331498  {'country': 'Croatia', 'code': 'CRO', 'goals':...
# 52  300331535  {'country': 'Brazil', 'code': 'BRA', 'goals': ...
# 53  300331551  {'country': 'Belgium', 'code': 'BEL', 'goals':...
# 54  300331514  {'country': 'Sweden', 'code': 'SWE', 'goals': ...
# 55  300331542  {'country': 'Colombia', 'code': 'COL', 'goals'...
# 56  300331543  {'country': 'Uruguay', 'code': 'URU', 'goals':...
# 57  300331538  {'country': 'Brazil', 'code': 'BRA', 'goals': ...
# 58  300331541  {'country': 'Sweden', 'code': 'SWE', 'goals': ...
# 59  300331504  {'country': 'Russia', 'code': 'RUS', 'goals': ...
# 60  300331531  {'country': 'France', 'code': 'FRA', 'goals': ...
# 61  300331522  {'country': 'Croatia', 'code': 'CRO', 'goals':...
# 62  300331536  {'country': 'Belgium', 'code': 'BEL', 'goals':...
# 63  300331552  {'country': 'France', 'code': 'FRA', 'goals': ...
#
#    home_team_country                                   home_team_events  \
# 0             Russia  [{'id': 5, 'type_of_event': 'goal', 'player': ...
# 1              Egypt  [{'id': 14, 'type_of_event': 'substitution-in'...
# 2            Morocco  [{'id': 23, 'type_of_event': 'yellow-card', 'p...
# 3           Portugal  [{'id': 36, 'type_of_event': 'goal-penalty', '...
# 4             France  [{'id': 52, 'type_of_event': 'goal-penalty', '...
# 5          Argentina  [{'id': 62, 'type_of_event': 'goal', 'player':...
# 6               Peru  [{'id': 71, 'type_of_event': 'yellow-card', 'p...
# 7            Croatia  [{'id': 80, 'type_of_event': 'yellow-card', 'p...
# 8         Costa Rica  [{'id': 99, 'type_of_event': 'yellow-card', 'p...
# 9            Germany  [{'id': 119, 'type_of_event': 'substitution-ou...
# 10            Brazil  [{'id': 132, 'type_of_event': 'goal', 'player'...
# 11            Sweden  [{'id': 156, 'type_of_event': 'yellow-card', '...
# 12           Belgium  [{'id': 166, 'type_of_event': 'yellow-card', '...
# 13           Tunisia  [{'id': 190, 'type_of_event': 'substitution-ou...
# 14          Colombia  [{'id': 203, 'type_of_event': 'red-card', 'pla...
# 15            Poland  [{'id': 222, 'type_of_event': 'yellow-card', '...
# 16            Russia  [{'id': 243, 'type_of_event': 'goal', 'player'...
# 17          Portugal  [{'id': 259, 'type_of_event': 'goal', 'player'...
# 18           Uruguay  [{'id': 276, 'type_of_event': 'goal', 'player'...
# 19              Iran  [{'id': 290, 'type_of_event': 'substitution-ou...
# 20           Denmark  [{'id': 355, 'type_of_event': 'goal', 'player'...
# 21            France  [{'id': 369, 'type_of_event': 'yellow-card', '...
# 22         Argentina  [{'id': 388, 'type_of_event': 'yellow-card', '...
# 23            Brazil  [{'id': 411, 'type_of_event': 'substitution-ou...
# 24           Nigeria  [{'id': 428, 'type_of_event': 'yellow-card', '...
# 25            Serbia  [{'id': 443, 'type_of_event': 'goal', 'player'...
# 26           Belgium  [{'id': 461, 'type_of_event': 'goal-penalty', ...
# 27    Korea Republic  [{'id': 483, 'type_of_event': 'yellow-card', '...
# 28           Germany  [{'id': 501, 'type_of_event': 'substitution-ou...
# 29           England  [{'id': 520, 'type_of_event': 'goal', 'player'...
# ..               ...                                                ...
# 34             Spain  [{'id': 618, 'type_of_event': 'goal', 'player'...
# 35              Iran  [{'id': 626, 'type_of_event': 'yellow-card', '...
# 36           Denmark  [{'id': 664, 'type_of_event': 'yellow-card', '...
# 37         Australia  [{'id': 661, 'type_of_event': 'yellow-card', '...
# 38           Iceland  [{'id': 703, 'type_of_event': 'yellow-card', '...
# 39           Nigeria  [{'id': 696, 'type_of_event': 'yellow-card', '...
# 40    Korea Republic  [{'id': 739, 'type_of_event': 'yellow-card', '...
# 41            Mexico  [{'id': 738, 'type_of_event': 'yellow-card', '...
# 42       Switzerland  [{'id': 780, 'type_of_event': 'goal', 'player'...
# 43            Serbia  [{'id': 781, 'type_of_event': 'yellow-card', '...
# 44             Japan  [{'id': 819, 'type_of_event': 'substitution-ou...
# 45           Senegal  [{'id': 821, 'type_of_event': 'yellow-card', '...
# 46           England  [{'id': 848, 'type_of_event': 'substitution-ou...
# 47            Panama  [{'id': 845, 'type_of_event': 'goal', 'player'...
# 48            France  [{'id': 877, 'type_of_event': 'goal-penalty', ...
# 49           Uruguay  [{'id': 903, 'type_of_event': 'goal', 'player'...
# 50             Spain  [{'id': 920, 'type_of_event': 'yellow-card', '...
# 51           Croatia  [{'id': 943, 'type_of_event': 'goal', 'player'...
# 52            Brazil  [{'id': 964, 'type_of_event': 'yellow-card', '...
# 53           Belgium  [{'id': 986, 'type_of_event': 'substitution-ou...
# 54            Sweden  [{'id': 997, 'type_of_event': 'yellow-card', '...
# 55          Colombia  [{'id': 1012, 'type_of_event': 'yellow-card', ...
# 56           Uruguay  [{'id': 1042, 'type_of_event': 'yellow-card', ...
# 57            Brazil  [{'id': 1058, 'type_of_event': 'goal-own', 'pl...
# 58            Sweden  [{'id': 1078, 'type_of_event': 'substitution-o...
# 59            Russia  [{'id': 1094, 'type_of_event': 'goal', 'player...
# 60            France  [{'id': 1121, 'type_of_event': 'goal', 'player...
# 61           Croatia  [{'id': 1138, 'type_of_event': 'yellow-card', ...
# 62           Belgium  [{'id': 1160, 'type_of_event': 'goal', 'player...
# 63            France  [{'id': 1179, 'type_of_event': 'yellow-card', ...
#
#        ...      last_score_update_at                  location  \
# 0      ...                      None          Luzhniki Stadium
# 1      ...                      None        Ekaterinburg Arena
# 2      ...                      None  Saint Petersburg Stadium
# 3      ...      2018-06-15T19:52:38Z             Fisht Stadium
# 4      ...      2018-06-16T11:52:21Z               Kazan Arena
# 5      ...      2018-06-16T14:54:29Z           Spartak Stadium
# 6      ...      2018-06-16T16:55:28Z            Mordovia Arena
# 7      ...      2018-06-16T20:53:41Z       Kaliningrad Stadium
# 8      ...      2018-06-17T13:54:55Z              Samara Arena
# 9      ...      2018-06-17T16:50:54Z          Luzhniki Stadium
# 10     ...      2018-06-17T19:55:21Z              Rostov Arena
# 11     ...      2018-06-18T13:50:50Z   Nizhny Novgorod Stadium
# 12     ...      2018-06-18T16:53:29Z             Fisht Stadium
# 13     ...      2018-06-18T19:54:06Z           Volgograd Arena
# 14     ...      2018-06-19T13:52:45Z            Mordovia Arena
# 15     ...      2018-06-19T16:53:34Z           Spartak Stadium
# 16     ...      2018-06-19T19:51:07Z  Saint Petersburg Stadium
# 17     ...      2018-06-20T13:55:28Z          Luzhniki Stadium
# 18     ...      2018-06-20T16:52:56Z              Rostov Arena
# 19     ...      2018-06-20T19:50:29Z               Kazan Arena
# 20     ...      2018-06-22T00:00:03Z              Samara Arena
# 21     ...      2018-06-21T23:59:50Z        Ekaterinburg Arena
# 22     ...      2018-06-21T23:59:57Z   Nizhny Novgorod Stadium
# 23     ...      2018-06-22T13:55:03Z  Saint Petersburg Stadium
# 24     ...      2018-06-22T16:56:15Z           Volgograd Arena
# 25     ...      2018-06-22T19:54:18Z       Kaliningrad Stadium
# 26     ...      2018-06-23T13:55:55Z           Spartak Stadium
# 27     ...      2018-06-23T16:53:31Z              Rostov Arena
# 28     ...      2018-06-23T19:55:53Z             Fisht Stadium
# 29     ...      2018-06-24T13:53:42Z   Nizhny Novgorod Stadium
# ..     ...                       ...                       ...
# 34     ...      2018-06-25T19:56:26Z       Kaliningrad Stadium
# 35     ...      2018-06-25T19:57:13Z            Mordovia Arena
# 36     ...      2018-06-26T15:51:55Z          Luzhniki Stadium
# 37     ...      2018-06-26T15:53:54Z             Fisht Stadium
# 38     ...      2018-06-26T19:52:36Z              Rostov Arena
# 39     ...      2018-06-26T19:54:06Z  Saint Petersburg Stadium
# 40     ...      2018-06-27T15:58:47Z               Kazan Arena
# 41     ...      2018-06-27T15:53:43Z        Ekaterinburg Arena
# 42     ...      2018-06-27T19:54:11Z   Nizhny Novgorod Stadium
# 43     ...      2018-06-27T19:51:47Z           Spartak Stadium
# 44     ...      2018-06-28T15:52:28Z           Volgograd Arena
# 45     ...      2018-06-28T15:54:03Z              Samara Arena
# 46     ...      2018-06-28T19:51:13Z       Kaliningrad Stadium
# 47     ...      2018-06-28T19:56:36Z            Mordovia Arena
# 48     ...      2018-06-30T17:16:20Z               Kazan Arena
# 49     ...      2018-06-30T19:55:36Z             Fisht Stadium
# 50     ...      2018-07-01T16:53:15Z          Luzhniki Stadium
# 51     ...      2018-07-01T20:46:51Z   Nizhny Novgorod Stadium
# 52     ...      2018-07-02T15:52:39Z              Samara Arena
# 53     ...      2018-07-02T19:54:06Z              Rostov Arena
# 54     ...      2018-07-03T15:53:44Z  Saint Petersburg Stadium
# 55     ...      2018-07-03T20:53:13Z           Spartak Stadium
# 56     ...      2018-07-06T15:53:30Z   Nizhny Novgorod Stadium
# 57     ...      2018-07-06T19:53:42Z               Kazan Arena
# 58     ...      2018-07-07T15:52:32Z              Samara Arena
# 59     ...      2018-07-07T20:51:30Z             Fisht Stadium
# 60     ...      2018-07-10T19:54:35Z  Saint Petersburg Stadium
# 61     ...      2018-07-11T20:37:36Z          Luzhniki Stadium
# 62     ...      2018-07-14T15:52:28Z  Saint Petersburg Stadium
# 63     ...      2018-07-15T16:54:32Z          Luzhniki Stadium
#
#                                             officials  \
# 0   [Nestor PITANA, Hernan MAIDANA, Juan Pablo BEL...
# 1   [Bjorn KUIPERS, Sander VAN ROEKEL, Erwin ZEINS...
# 2   [Cuneyt CAKIR, Bahattin DURAN, Tarik ONGUN, Se...
# 3   [Gianluca ROCCHI, Elenito DI LIBERATORE, Mauro...
# 4   [Andres CUNHA, Nicolas TARAN, Mauricio ESPINOS...
# 5   [Szymon MARCINIAK, Pawel SOKOLNICKI, Tomasz LI...
# 6   [Bakary GASSAMA, Jean Claude BIRUMUSHAHU, Abde...
# 7   [Sandro RICCI, Emerson DE CARVALHO, Marcelo VA...
# 8   [Malang DIEDHIOU, Djibril CAMARA, El Hadji SAM...
# 9   [Alireza FAGHANI, Reza SOKHANDAN, Mohammadreza...
# 10  [Cesar RAMOS, Marvin TORRENTERA, Miguel HERNAN...
# 11  [Joel AGUILAR, Juan ZUMBA, Juan Carlos MORA, N...
# 12  [Janny SIKAZWE, Jerson DOS SANTOS, Zakhele SIW...
# 13  [Wilmar ROLDAN, Alexander GUZMAN, Cristian DE ...
# 14  [Damir SKOMINA, Jure PRAPROTNIK, Robert VUKAN,...
# 15  [Nawaf SHUKRALLA, Yaser TULEFAT, Taleb AL MARR...
# 16  [Enrique CACERES, Eduardo CARDOZO, Juan ZORRIL...
# 17  [Mark GEIGER, Joe FLETCHER, Frank ANDERSON, Se...
# 18  [Clement TURPIN, Nicolas DANOS, Cyril GRINGORE...
# 19  [Andres CUNHA, Nicolas TARAN, Mauricio ESPINOS...
# 20  [Antonio MATEU, Pau CEBRIAN, Roberto DIAZ, Bam...
# 21  [Mohammed Abdulla MOHAMMED, Mohamed ALHAMMADI,...
# 22  [Ravshan IRMATOV, Abdukhamidullo RASULOV, Jakh...
# 23  [Bjorn KUIPERS, Sander VAN ROEKEL, Erwin ZEINS...
# 24  [Matt CONGER, Simon LOUNT, Tevita MAKASINI, Ri...
# 25  [Felix BRYCH, Mark BORSCH, Stefan LUPP, Nawaf ...
# 26  [Jair MARRUFO, Corey ROCKWELL, Juan ZUMBA, And...
# 27  [Milorad MAZIC, Milovan RISTIC, Dalibor DJURDJ...
# 28  [Szymon MARCINIAK, Pawel SOKOLNICKI, Tomasz LI...
# 29  [Ghead GRISHA, Redouane ACHIK, Waleed AHMED, N...
# ..                                                ...
# 34  [Ravshan IRMATOV, Abdukhamidullo RASULOV, Jakh...
# 35  [Enrique CACERES, Eduardo CARDOZO, Juan ZORRIL...
# 36  [Sandro RICCI, Emerson DE CARVALHO, Marcelo VA...
# 37  [Sergei KARASEV, Anton AVERIANOV, Tikhon KALUG...
# 38  [Antonio MATEU, Pau CEBRIAN, Roberto DIAZ, Joh...
# 39  [Cuneyt CAKIR, Bahattin DURAN, Tarik ONGUN, Bj...
# 40  [Mark GEIGER, Joe FLETCHER, Frank ANDERSON, Ju...
# 41  [Nestor PITANA, Hernan MAIDANA, Juan Pablo BEL...
# 42  [Clement TURPIN, Nicolas DANOS, Cyril GRINGORE...
# 43  [Alireza FAGHANI, Reza SOKHANDAN, Mohammadreza...
# 44  [Janny SIKAZWE, Jerson DOS SANTOS, Zakhele SIW...
# 45  [Milorad MAZIC, Milovan RISTIC, Dalibor DJURDJ...
# 46  [Damir SKOMINA, Jure PRAPROTNIK, Robert VUKAN,...
# 47  [Nawaf SHUKRALLA, Yaser TULEFAT, Taleb AL MARR...
# 48  [Alireza FAGHANI, Reza SOKHANDAN, Mohammadreza...
# 49  [Cesar RAMOS, Marvin TORRENTERA, Miguel HERNAN...
# 50  [Bjorn KUIPERS, Sander VAN ROEKEL, Erwin ZEINS...
# 51  [Nestor PITANA, Hernan MAIDANA, Juan Pablo BEL...
# 52  [Gianluca ROCCHI, Elenito DI LIBERATORE, Mauro...
# 53  [Malang DIEDHIOU, Djibril CAMARA, El Hadji SAM...
# 54  [Damir SKOMINA, Jure PRAPROTNIK, Robert VUKAN,...
# 55  [Mark GEIGER, Joe FLETCHER, Frank ANDERSON, Ma...
# 56  [Nestor PITANA, Hernan MAIDANA, Juan Pablo BEL...
# 57  [Milorad MAZIC, Milovan RISTIC, Dalibor DJURDJ...
# 58  [Bjorn KUIPERS, Sander VAN ROEKEL, Erwin ZEINS...
# 59  [Sandro RICCI, Emerson DE CARVALHO, Marcelo VA...
# 60  [Andres CUNHA, Nicolas TARAN, Mauricio ESPINOS...
# 61  [Cuneyt CAKIR, Bahattin DURAN, Tarik ONGUN, Bj...
# 62  [Alireza FAGHANI, Reza SOKHANDAN, Mohammadreza...
# 63  [Nestor PITANA, Hernan MAIDANA, Juan Pablo BEL...
#
#                   stage_name     status       time            venue  \
# 0                First stage  completed  full-time           Moscow
# 1                First stage  completed  full-time     Ekaterinburg
# 2                First stage  completed  full-time   St. Petersburg
# 3                First stage  completed  full-time            Sochi
# 4                First stage  completed  full-time            Kazan
# 5                First stage  completed  full-time           Moscow
# 6                First stage  completed  full-time          Saransk
# 7                First stage  completed  full-time      Kaliningrad
# 8                First stage  completed  full-time           Samara
# 9                First stage  completed  full-time           Moscow
# 10               First stage  completed  full-time    Rostov-On-Don
# 11               First stage  completed  full-time  Nizhny Novgorod
# 12               First stage  completed  full-time            Sochi
# 13               First stage  completed  full-time        Volgograd
# 14               First stage  completed  full-time          Saransk
# 15               First stage  completed  full-time           Moscow
# 16               First stage  completed  full-time   St. Petersburg
# 17               First stage  completed  full-time           Moscow
# 18               First stage  completed  full-time    Rostov-On-Don
# 19               First stage  completed  full-time            Kazan
# 20               First stage  completed  full-time           Samara
# 21               First stage  completed  full-time     Ekaterinburg
# 22               First stage  completed  full-time  Nizhny Novgorod
# 23               First stage  completed  full-time   St. Petersburg
# 24               First stage  completed  full-time        Volgograd
# 25               First stage  completed  full-time      Kaliningrad
# 26               First stage  completed  full-time           Moscow
# 27               First stage  completed  full-time    Rostov-On-Don
# 28               First stage  completed  full-time            Sochi
# 29               First stage  completed  full-time  Nizhny Novgorod
# ..                       ...        ...        ...              ...
# 34               First stage  completed  full-time      Kaliningrad
# 35               First stage  completed  full-time          Saransk
# 36               First stage  completed  full-time           Moscow
# 37               First stage  completed  full-time            Sochi
# 38               First stage  completed  full-time    Rostov-On-Don
# 39               First stage  completed  full-time   St. Petersburg
# 40               First stage  completed  full-time            Kazan
# 41               First stage  completed  full-time     Ekaterinburg
# 42               First stage  completed  full-time  Nizhny Novgorod
# 43               First stage  completed  full-time           Moscow
# 44               First stage  completed  full-time        Volgograd
# 45               First stage  completed  full-time           Samara
# 46               First stage  completed  full-time      Kaliningrad
# 47               First stage  completed  full-time          Saransk
# 48               Round of 16  completed  full-time            Kazan
# 49               Round of 16  completed  full-time            Sochi
# 50               Round of 16  completed  full-time           Moscow
# 51               Round of 16  completed  full-time  Nizhny Novgorod
# 52               Round of 16  completed  full-time           Samara
# 53               Round of 16  completed  full-time    Rostov-On-Don
# 54               Round of 16  completed  full-time   St. Petersburg
# 55               Round of 16  completed  full-time           Moscow
# 56            Quarter-finals  completed  full-time  Nizhny Novgorod
# 57            Quarter-finals  completed  full-time            Kazan
# 58            Quarter-finals  completed  full-time           Samara
# 59            Quarter-finals  completed  full-time            Sochi
# 60               Semi-finals  completed  full-time   St. Petersburg
# 61               Semi-finals  completed  full-time           Moscow
# 62  Play-off for third place  completed  full-time   St. Petersburg
# 63                     Final  completed  full-time           Moscow
#
#                                               weather          winner  \
# 0   {'humidity': '43', 'temp_celsius': '17', 'temp...          Russia
# 1   {'humidity': '42', 'temp_celsius': '14', 'temp...         Uruguay
# 2   {'humidity': '37', 'temp_celsius': '25', 'temp...            Iran
# 3   {'humidity': '74', 'temp_celsius': '24', 'temp...            Draw
# 4   {'humidity': '32', 'temp_celsius': '19', 'temp...          France
# 5   {'humidity': '33', 'temp_celsius': '22', 'temp...            Draw
# 6   {'humidity': '48', 'temp_celsius': '18', 'temp...         Denmark
# 7   {'humidity': '64', 'temp_celsius': '20', 'temp...         Croatia
# 8   {'humidity': '32', 'temp_celsius': '22', 'temp...          Serbia
# 9   {'humidity': '42', 'temp_celsius': '23', 'temp...          Mexico
# 10  {'humidity': '27', 'temp_celsius': '25', 'temp...            Draw
# 11  {'humidity': '36', 'temp_celsius': '25', 'temp...          Sweden
# 12  {'humidity': '71', 'temp_celsius': '24', 'temp...         Belgium
# 13  {'humidity': '17', 'temp_celsius': '24', 'temp...         England
# 14  {'humidity': '38', 'temp_celsius': '27', 'temp...           Japan
# 15  {'humidity': '40', 'temp_celsius': '27', 'temp...         Senegal
# 16  {'humidity': '83', 'temp_celsius': '15', 'temp...          Russia
# 17  {'humidity': '33', 'temp_celsius': '20', 'temp...        Portugal
# 18  {'humidity': '26', 'temp_celsius': '32', 'temp...         Uruguay
# 19  {'humidity': '48', 'temp_celsius': '18', 'temp...           Spain
# 20  {'humidity': '32', 'temp_celsius': '24', 'temp...            Draw
# 21  {'humidity': '79', 'temp_celsius': '12', 'temp...          France
# 22  {'humidity': '49', 'temp_celsius': '17', 'temp...         Croatia
# 23  {'humidity': '70', 'temp_celsius': '19', 'temp...          Brazil
# 24  {'humidity': '19', 'temp_celsius': '32', 'temp...         Nigeria
# 25  {'humidity': '55', 'temp_celsius': '15', 'temp...     Switzerland
# 26  {'humidity': '64', 'temp_celsius': '28', 'temp...         Belgium
# 27  {'humidity': '28', 'temp_celsius': '33', 'temp...          Mexico
# 28  {'humidity': '80', 'temp_celsius': '22', 'temp...         Germany
# 29  {'humidity': '33', 'temp_celsius': '30', 'temp...         England
# ..                                                ...             ...
# 34  {'humidity': '70', 'temp_celsius': '15', 'temp...            Draw
# 35  {'humidity': '70', 'temp_celsius': '23', 'temp...            Draw
# 36  {'humidity': '34', 'temp_celsius': '24', 'temp...            Draw
# 37  {'humidity': '70', 'temp_celsius': '30', 'temp...            Peru
# 38  {'humidity': '38', 'temp_celsius': '30', 'temp...         Croatia
# 39  {'humidity': '45', 'temp_celsius': '22', 'temp...       Argentina
# 40  {'humidity': '40', 'temp_celsius': '28', 'temp...  Korea Republic
# 41  {'humidity': '42', 'temp_celsius': '27', 'temp...          Sweden
# 42  {'humidity': '43', 'temp_celsius': '20', 'temp...            Draw
# 43  {'humidity': '42', 'temp_celsius': '24', 'temp...          Brazil
# 44  {'humidity': '24', 'temp_celsius': '36', 'temp...          Poland
# 45  {'humidity': '34', 'temp_celsius': '27', 'temp...        Colombia
# 46  {'humidity': '61', 'temp_celsius': '21', 'temp...         Belgium
# 47  {'humidity': '60', 'temp_celsius': '20', 'temp...         Tunisia
# 48  {'humidity': '33', 'temp_celsius': '28', 'temp...          France
# 49  {'humidity': '74', 'temp_celsius': '27', 'temp...         Uruguay
# 50  {'humidity': '63', 'temp_celsius': '24', 'temp...          Russia
# 51  {'humidity': '48', 'temp_celsius': '25', 'temp...         Croatia
# 52  {'humidity': '28', 'temp_celsius': '33', 'temp...          Brazil
# 53  {'humidity': '36', 'temp_celsius': '25', 'temp...         Belgium
# 54  {'humidity': '60', 'temp_celsius': '18', 'temp...          Sweden
# 55  {'humidity': '61', 'temp_celsius': '18', 'temp...         England
# 56  {'humidity': '53', 'temp_celsius': '22', 'temp...          France
# 57  {'humidity': '60', 'temp_celsius': '20', 'temp...         Belgium
# 58  {'humidity': '39', 'temp_celsius': '26', 'temp...         England
# 59  {'humidity': '70', 'temp_celsius': '24', 'temp...         Croatia
# 60  {'humidity': '75', 'temp_celsius': '18', 'temp...          France
# 61  {'humidity': '64', 'temp_celsius': '21', 'temp...         Croatia
# 62  {'humidity': '45', 'temp_celsius': '26', 'temp...         Belgium
# 63  {'humidity': '51', 'temp_celsius': '27', 'temp...          France
#
#    winner_code
# 0          RUS
# 1          URU
# 2          IRN
# 3         Draw
# 4          FRA
# 5         Draw
# 6          DEN
# 7          CRO
# 8          SRB
# 9          MEX
# 10        Draw
# 11         SWE
# 12         BEL
# 13         ENG
# 14         JPN
# 15         SEN
# 16         RUS
# 17         POR
# 18         URU
# 19         ESP
# 20        Draw
# 21         FRA
# 22         CRO
# 23         BRA
# 24         NGA
# 25         SUI
# 26         BEL
# 27         MEX
# 28         GER
# 29         ENG
# ..         ...
# 34        Draw
# 35        Draw
# 36        Draw
# 37         PER
# 38         CRO
# 39         ARG
# 40         KOR
# 41         SWE
# 42        Draw
# 43         BRA
# 44         POL
# 45         COL
# 46         BEL
# 47         TUN
# 48         FRA
# 49         URU
# 50         RUS
# 51         CRO
# 52         BRA
# 53         BEL
# 54         SWE
# 55         ENG
# 56         FRA
# 57         BEL
# 58         ENG
# 59         CRO
# 60         FRA
# 61         CRO
# 62         BEL
# 63         FRA
#
# [64 rows x 22 columns]

# %%
# hum = []
# tempC = []
# tempF = []
# windsp = []
# disc = []


# for i in range(len(match_df["weather"])):

#     #grab country names, locations, and weather conditions

#     hum1 = match_df["weather"][i]['humidity']
#     tempC1 = match_df["weather"][i]['temp_celsius']
#     tempF1 = match_df["weather"][i]["temp_farenheit"]
#     windsp1 = match_df["weather"][i]['wind_speed']
#     disc1 = match_df["weather"][i]['description']
#     hum.append(hum1)
#     tempC.append(tempC1)
#     tempF.append(tempF1)
#     windsp.append(windsp1)
#     disc.append(disc1)    

# weather_df = pd.DataFrame({"Humidity":hum,
#                            "Temperature C":tempC,
#                            "Temeprature F":tempF,
#                            "Wind Speed":windsp,
#                            "Description":disc
#                           })
# weather_df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
hum = []
tempC = []
tempF = []
windsp = []
disc = []


for i in range(len(match_df["weather"])):

    #grab country names, locations, and weather conditions
    hum1 = match_df["weather"][i]['humidity']
    tempC1 = match_df["weather"][i]['temp_celsius']
    tempF1 = match_df["weather"][i]["temp_farenheit"]
    windsp1 = match_df["weather"][i]['wind_speed']
    disc1 = match_df["weather"][i]['description']
    hum.append(hum1)
    tempC.append(tempC1)
    tempF.append(tempF1)
    windsp.append(windsp1)
    disc.append(disc1)    

weather_df = pd.DataFrame({"Humidity":hum,
                           "Temperature C":tempC,
                           "Temeprature F":tempF,
                           "Wind Speed":windsp,
                           "Description":disc
                          })
weather_df
# Out:
#    Humidity Temperature C Temeprature F Wind Speed          Description
# 0        43            17            49          6        Partly Cloudy
# 1        42            14            46         29        Partly Cloudy
# 2        37            25            57         13        Partly Cloudy
# 3        74            24            56         10  Partly Cloudy Night
# 4        32            19            51         19                Sunny
# 5        33            22            54         11                Sunny
# 6        48            18            50         12        Partly Cloudy
# 7        64            20            52          7        Partly Cloudy
# 8        32            22            54         18                Sunny
# 9        42            23            55         11                Sunny
# 10       27            25            57         16  Partly Cloudy Night
# 11       36            25            57          9        Partly Cloudy
# 12       71            24            56         12        Partly Cloudy
# 13       17            24            56          7          Clear Night
# 14       38            27            59         12                Sunny
# 15       40            27            59         19               Cloudy
# 16       83            15            47         14               Cloudy
# 17       33            20            52         24        Partly Cloudy
# 18       26            32            64         10                Sunny
# 19       48            18            50         26          Clear Night
# 20       32            24            56         25                Sunny
# 21       79            12            44         21               Cloudy
# 22       49            17            49         15          Clear Night
# 23       70            19            51         19               Cloudy
# 24       19            32            64          2                Sunny
# 25       55            15            47         11                Sunny
# 26       64            28            60         12        Partly Cloudy
# 27       28            33            65         11        Partly Cloudy
# 28       80            22            54         11  Partly Cloudy Night
# 29       33            30            62         15        Partly Cloudy
# ..      ...           ...           ...        ...                  ...
# 34       70            15            47         13  Partly Cloudy Night
# 35       70            23            55          9  Partly Cloudy Night
# 36       34            24            56         11        Partly Cloudy
# 37       70            30            62         10        Partly Cloudy
# 38       38            30            62         21          Clear Night
# 39       45            22            54         18                Sunny
# 40       40            28            60         18                Sunny
# 41       42            27            59         18                Sunny
# 42       43            20            52         13          Clear Night
# 43       42            24            56         12        Partly Cloudy
# 44       24            36            68         13                Sunny
# 45       34            27            59         21                Sunny
# 46       61            21            53         11                Sunny
# 47       60            20            52          7          Clear Night
# 48       33            28            60         12                Sunny
# 49       74            27            59         11          Clear Night
# 50       63            24            56         13        Partly Cloudy
# 51       48            25            57         15  Partly Cloudy Night
# 52       28            33            65         14                Sunny
# 53       36            25            57          9          Clear Night
# 54       60            18            50         10        Partly Cloudy
# 55       61            18            50          7               Cloudy
# 56       53            22            54         13        Partly Cloudy
# 57       60            20            52          9  Partly Cloudy Night
# 58       39            26            58          7        Partly Cloudy
# 59       70            24            56         12          Clear Night
# 60       75            18            50         11               Cloudy
# 61       64            21            53          6               Cloudy
# 62       45            26            58         10        Partly Cloudy
# 63       51            27            59          3        Partly Cloudy
#
# [64 rows x 5 columns]

# %%
print(foul_avg)

games_won = []
#calculate average fouls based on foul dictionary
for country in teams_df['country']:
    games = teams_df.loc[country, 'games_played']
    att_avg[country] = foul_avg[country]/games
    won = teams_df.loc[country, 'points']
    games_won.append(won)
# Out:
# {'Russia': 95, 'Saudi Arabia': 30, 'Egypt': 38, 'Uruguay': 61, 'Morocco': 62, 'Iran': 44, 'Portugal': 55, 'Spain': 34, 'France': 78, 'Australia': 37, 'Argentina': 55, 'Iceland': 34, 'Peru': 37, 'Denmark': 54, 'Croatia': 100, 'Nigeria': 46, 'Costa Rica': 43, 'Serbia': 45, 'Germany': 29, 'Mexico': 54, 'Brazil': 50, 'Switzerland': 52, 'Sweden': 64, 'Korea Republic': 62, 'Belgium': 97, 'Panama': 35, 'Tunisia': 46, 'England': 58, 'Colombia': 53, 'Japan': 29, 'Poland': 16, 'Senegal': 30}

# %%
plt.bar(range(len(foul_avg)), list(foul_avg.values()), align='center')
plt.xticks(range(len(foul_avg)), list(foul_avg.keys()), rotation = 90)

#country's foul average per game
# Out:
# ([<matplotlib.axis.XTick at 0x1b2909aaf60>,
#   <matplotlib.axis.XTick at 0x1b2909aa828>,
#   <matplotlib.axis.XTick at 0x1b2909aa2b0>,
#   <matplotlib.axis.XTick at 0x1b290a15128>,
#   <matplotlib.axis.XTick at 0x1b290a15160>,
#   <matplotlib.axis.XTick at 0x1b290a15978>,
#   <matplotlib.axis.XTick at 0x1b290a15e80>,
#   <matplotlib.axis.XTick at 0x1b290a1d3c8>,
#   <matplotlib.axis.XTick at 0x1b290a1d8d0>,
#   <matplotlib.axis.XTick at 0x1b290a1ddd8>,
#   <matplotlib.axis.XTick at 0x1b290a24320>,
#   <matplotlib.axis.XTick at 0x1b290a24828>,
#   <matplotlib.axis.XTick at 0x1b290a24d30>,
#   <matplotlib.axis.XTick at 0x1b290a247f0>,
#   <matplotlib.axis.XTick at 0x1b290a1d978>,
#   <matplotlib.axis.XTick at 0x1b290a157f0>,
#   <matplotlib.axis.XTick at 0x1b290a2c6a0>,
#   <matplotlib.axis.XTick at 0x1b290a2cba8>,
#   <matplotlib.axis.XTick at 0x1b290a35160>,
#   <matplotlib.axis.XTick at 0x1b290a355f8>,
#   <matplotlib.axis.XTick at 0x1b290a35b00>,
#   <matplotlib.axis.XTick at 0x1b290a3e0b8>,
#   <matplotlib.axis.XTick at 0x1b290a3e550>,
#   <matplotlib.axis.XTick at 0x1b290a35400>,
#   <matplotlib.axis.XTick at 0x1b290a15780>,
#   <matplotlib.axis.XTick at 0x1b290a3e898>,
#   <matplotlib.axis.XTick at 0x1b290a3eda0>,
#   <matplotlib.axis.XTick at 0x1b290a452e8>,
#   <matplotlib.axis.XTick at 0x1b290a457f0>,
#   <matplotlib.axis.XTick at 0x1b290a45cf8>,
#   <matplotlib.axis.XTick at 0x1b290a4e240>,
#   <matplotlib.axis.XTick at 0x1b290a4e748>],
#  <a list of 32 Text xticklabel objects>)

# %%
plt.bar(['winning', 'losing'],[winning_fouls_total, losing_fouls_total])
#total fouls
# Out:
# <BarContainer object of 2 artists>

# %%
#games won vs avg fouls
plt.scatter(games_won, list(foul_avg.values()))

# %%
# Out:
#                                                           a  \
# matches   [{'name': 1, 'type': 'group', 'home_team': 1, ...
# name                                                Group A
# runnerup                                                  1
# winner                                                    4
#
#                                                           b  \
# matches   [{'name': 3, 'type': 'group', 'home_team': 5, ...
# name                                                Group B
# runnerup                                                  5
# winner                                                    6
#
#                                                           c  \
# matches   [{'name': 5, 'type': 'group', 'home_team': 9, ...
# name                                                Group C
# runnerup                                                 12
# winner                                                    9
#
#                                                           d  \
# matches   [{'name': 7, 'type': 'group', 'home_team': 13,...
# name                                                Group D
# runnerup                                                 13
# winner                                                   15
#
#                                                           e  \
# matches   [{'name': 9, 'type': 'group', 'home_team': 17,...
# name                                                Group E
# runnerup                                                 18
# winner                                                   17
#
#                                                           f  \
# matches   [{'name': 11, 'type': 'group', 'home_team': 21...
# name                                                Group F
# runnerup                                                 22
# winner                                                   23
#
#                                                           g  \
# matches   [{'name': 13, 'type': 'group', 'home_team': 25...
# name                                                Group G
# runnerup                                                 28
# winner                                                   25
#
#                                                           h
# matches   [{'name': 15, 'type': 'group', 'home_team': 29...
# name                                                Group H
# runnerup                                                 32
# winner                                                   31

# %%
# Out:
#                                              matches
# a  [{'name': 1, 'type': 'group', 'home_team': 1, ...
# b  [{'name': 3, 'type': 'group', 'home_team': 5, ...
# c  [{'name': 5, 'type': 'group', 'home_team': 9, ...
# d  [{'name': 7, 'type': 'group', 'home_team': 13,...
# e  [{'name': 9, 'type': 'group', 'home_team': 17,...
# f  [{'name': 11, 'type': 'group', 'home_team': 21...
# g  [{'name': 13, 'type': 'group', 'home_team': 25...
# h  [{'name': 15, 'type': 'group', 'home_team': 29...

# %%
# Out:
# matches    [{'name': 1, 'type': 'group', 'home_team': 1, ...
# Name: a, dtype: object
